# %%
#HEART ATTACK PROBABILITY ANALYSIS USING SUPPORT VECTOR MACHINE MODEL

# %%
# Import dependency modules
# %matplotlib notebook
import warnings
warnings.filterwarnings('ignore')
import matplotlib.pyplot as plt
import pandas as pd
import numpy as np

# %%
#define relative filepath for dataset:
heartFile= "resources/heart.csv"
#open csv to pandas dataframe:
heartData=pd.read_csv(heartFile)

# %%
#define X and y:
y=heartData.target.values.ravel()
X=heartData.drop("target", axis=1)
print(X.shape, y.shape)
# Out:
# (303, 13) (303,)

# %%
# test train split the data:
from sklearn.model_selection import train_test_split
x_train, x_test, y_train, y_test= train_test_split(X, y, random_state=42)

# %%
#Scale the data using Standard Scaler, do not scale y data as it is binomial categories
from sklearn.preprocessing import StandardScaler
x_scaler= StandardScaler().fit(x_train)
x_train_scaled = x_scaler.transform(x_train)
x_test_scaled= x_scaler.transform(x_test)

# %%
# Create SVC Model:
from sklearn.svm import SVC
model=SVC()
# import grid search and select parameters of SVC to tune
from sklearn.model_selection import GridSearchCV

# %%
# define grid params and fit the grid
params={'kernel': ['linear', 'poly', 'rbf', 'sigmoid'],
        'C': [.00001,.0001, .001, .01, .1, 1],
        'gamma':[0.1, 1, 10, 100],
        'degree': [1, 2, 3, 4, 5, 6],
        'class_weight':['balanced', None]
       }
grid=GridSearchCV(model, params, verbose=3, scoring = 'f1')
grid.fit(x_train_scaled, y_train)
# Out:
# Fitting 5 folds for each of 1152 candidates, totalling 5760 fits
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly, score=0.000, total=   0.0s
# [Parallel(n_jobs=1)]: Using backend SequentialBackend with 1 concurrent workers.
# [Parallel(n_jobs=1)]: Done   1 out of   1 | elapsed:    0.0s remaining:    0.0s
# [Parallel(n_jobs=1)]: Done   2 out of   2 | elapsed:    0.0s remaining:    0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly, score=0.769, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly, score=0.781, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly, score=0.756, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly, score=0.791, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=poly, score=0.683, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=1, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly, score=0.738, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly, score=0.738, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly, score=0.698, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly, score=0.742, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=poly, score=0.687, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly, score=0.625, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly, score=0.727, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly, score=0.625, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly, score=0.578, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=poly, score=0.553, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=2, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly, score=0.758, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly, score=0.735, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly, score=0.716, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly, score=0.769, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=poly, score=0.714, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly, score=0.792, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly, score=0.800, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly, score=0.745, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly, score=0.784, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=poly, score=0.708, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf ..
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=10, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly, score=0.840, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly, score=0.800, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly, score=0.720, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly, score=0.784, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=poly, score=0.681, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=3, gamma=100, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=poly, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf .
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=0.1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=linear, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly, score=0.735, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly, score=0.758, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly, score=0.687, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly, score=0.762, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly ..
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=poly, score=0.719, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf ...
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=rbf, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid, score=0.704, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid
# [CV]  C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid, score=0.000, total=   0.0s
# [CV] C=1e-05, class_weight=balanced, degree=4, gamma=1, kernel=sigmoid
# ...
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=linear, score=0.809, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=poly, score=0.808, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=poly, score=0.786, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=poly, score=0.691, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=poly, score=0.786, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=poly, score=0.755, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=rbf, score=0.696, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid, score=0.638, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid, score=0.830, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid, score=0.824, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid, score=0.786, total=   0.0s
# [CV] C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=5, gamma=100, kernel=sigmoid, score=0.800, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear, score=0.776, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear, score=0.880, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear, score=0.764, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear, score=0.873, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=linear, score=0.809, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly, score=0.700, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly, score=0.738, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly, score=0.677, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly, score=0.730, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=poly, score=0.721, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf, score=0.792, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf, score=0.808, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf, score=0.836, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf, score=0.857, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=rbf, score=0.826, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid, score=0.750, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid, score=0.830, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid, score=0.800, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid, score=0.885, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=0.1, kernel=sigmoid, score=0.776, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=linear ........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=linear, score=0.776, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=linear ........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=linear, score=0.880, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=linear ........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=linear, score=0.764, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=linear ........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=linear, score=0.873, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=linear ........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=linear, score=0.809, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=poly ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=poly ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=poly, score=0.737, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=poly ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=poly, score=0.556, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=poly ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=poly, score=0.654, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=poly ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=poly, score=0.702, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=rbf ...........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=rbf ...........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=rbf ...........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=rbf, score=0.706, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=rbf ...........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=rbf, score=0.716, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=rbf ...........
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=rbf, score=0.738, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid .......
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid, score=0.634, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid .......
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid, score=0.755, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid .......
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid, score=0.766, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid .......
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid, score=0.830, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid .......
# [CV]  C=1, class_weight=None, degree=6, gamma=1, kernel=sigmoid, score=0.755, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=linear .......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=linear, score=0.776, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=linear .......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=linear, score=0.880, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=linear .......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=linear, score=0.764, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=linear .......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=linear, score=0.873, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=linear .......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=linear, score=0.809, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=poly .........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=poly .........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=poly, score=0.737, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=poly .........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=poly, score=0.556, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=poly .........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=poly, score=0.654, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=poly .........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=poly, score=0.702, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=rbf ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=rbf ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=rbf ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=rbf, score=0.696, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=rbf ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=rbf ..........
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid ......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid, score=0.622, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid ......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid, score=0.792, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid ......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid, score=0.776, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid ......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid, score=0.808, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid ......
# [CV]  C=1, class_weight=None, degree=6, gamma=10, kernel=sigmoid, score=0.720, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=linear, score=0.776, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=linear, score=0.880, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=linear, score=0.764, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=linear, score=0.873, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=linear ......
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=linear, score=0.809, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=poly, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=poly, score=0.737, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=poly, score=0.556, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=poly, score=0.654, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=poly ........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=poly, score=0.702, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=rbf, score=0.704, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=rbf, score=0.696, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=rbf .........
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=rbf, score=0.714, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid, score=0.638, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid, score=0.830, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid, score=0.824, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid, score=0.786, total=   0.0s
# [CV] C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid .....
# [CV]  C=1, class_weight=None, degree=6, gamma=100, kernel=sigmoid, score=0.800, total=   0.0s
# [Parallel(n_jobs=1)]: Done 5760 out of 5760 | elapsed:   21.6s finished
# GridSearchCV(estimator=SVC(),
#              param_grid={'C': [1e-05, 0.0001, 0.001, 0.01, 0.1, 1],
#                          'class_weight': ['balanced', None],
#                          'degree': [1, 2, 3, 4, 5, 6],
#                          'gamma': [0.1, 1, 10, 100],
#                          'kernel': ['linear', 'poly', 'rbf', 'sigmoid']},
#              scoring='f1', verbose=3)

# %%
print(grid.best_params_)
print(grid.best_score_)
# Out:
# {'C': 0.001, 'class_weight': None, 'degree': 1, 'gamma': 100, 'kernel': 'poly'}
# 0.8440401400514952

# %%
y_grid_predicted= grid.predict(x_test_scaled)

# %%
from sklearn.metrics import classification_report, confusion_matrix, f1_score, precision_score, recall_score, roc_auc_score
print('Confusion Matrix : \n' + str(confusion_matrix(y_test,y_grid_predicted)))
# Out:
# Confusion Matrix :
# [[28  7]
#  [ 3 38]]

# %%
#Function to plot intuitive confusion matrix 
# CODE BORROWED FROM https://github.com/rohanjoseph93/Python-for-data-science/blob/master/Grid%20Search%20-%20Breast%20Cancer.ipynb
import itertools
def plot_confusion_matrix(cm, classes,
                          normalize=False,
                          title='Confusion matrix',
                          cmap=plt.cm.Blues):
    """
    This function prints and plots the confusion matrix.
    Normalization can be applied by setting `normalize=True`.
    """
    if normalize:
        cm = cm.astype('float') / cm.sum(axis=1)[:, np.newaxis]
        print("Normalized confusion matrix")
    else:
        print('Confusion matrix, without normalization')

    print(cm)

    plt.imshow(cm, interpolation='nearest', cmap=cmap)
    plt.title(title)
    plt.colorbar()
    tick_marks = np.arange(len(classes))
    plt.xticks(tick_marks, classes, rotation=45)
    plt.yticks(tick_marks, classes)

    fmt = '.2f' if normalize else 'd'
    thresh = cm.max() / 2.
    for i, j in itertools.product(range(cm.shape[0]), range(cm.shape[1])):
        plt.text(j, i, format(cm[i, j], fmt),
                 horizontalalignment="center",
                 color="white" if cm[i, j] > thresh else "black")

    plt.ylabel('True label')
    plt.xlabel('Predicted label')
    plt.tight_layout()

# %%
# Compute confusion matrix
cnf_matrix_grid = confusion_matrix(y_test, y_grid_predicted)
np.set_printoptions(precision=2)

# %%
# Plot non-normalized confusion matrix
plt.figure()
class_names = [0,1]
plot_confusion_matrix(cnf_matrix_grid, classes=class_names,
                      title='Confusion matrix - SVC With Grid Search')
a = plt.gcf()
a.set_size_inches(8,4)
plt.show()
# Out:
# <img src="data:image/png;base64,..." width="800">
# Confusion matrix, without normalization
# [[28  7]
#  [ 3 38]]
